# %% [markdown]
# # IPTU loading <a href="https://colab.research.google.com/github/jvcanavarro/HackSerpro/blob/master/iptu_loading.ipynb" target="_parent"><img style="display:block;margin-right:0;margin-left:auto; margin-top:-.8em" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Requirements

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests

# %%
from IPython.display import HTML

# %% [markdown]
# ## Loading the files

# %%
# files, dataframes = ["IPTU_Part_01_750K.csv", "IPTU_Part_02_750K.csv", "IPTU_Part_03_970K.csv",
#                      "IPTU_Part_04_750K.csv", "IPTU_Part_05_750K.csv"], []
# 
# for file in files:
#     dataframes.append(pd.read_csv("datasets/iptu-sp/" + file, sep=";", encoding = "ISO-8859-1"))
#     
# iptu = pd.concat(dataframes,axis=0)
# 
# for df in dataframes:
#     del df
# 
# del dataframes, files

iptu = pd.read_csv("datasets/iptu-sp/iptu.csv", encoding="utf-8", sep=";")

# %%
HTML(iptu.head(5).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NUMERO DO CONTRIBUINTE</th>
#       <th>ANO DO EXERCICIO</th>
#       <th>NUMERO DA NL</th>
#       <th>DATA DO CADASTRAMENTO</th>
#       <th>TIPO DE CONTRIBUINTE 1</th>
#       <th>NOME DO CONTRIBUINTE 1</th>
#       <th>TIPO DE CONTRIBUINTE 2</th>
#       <th>NOME DO CONTRIBUINTE 2</th>
#       <th>NUMERO DO CONDOMINIO</th>
#       <th>CODLOG DO IMOVEL</th>
#       <th>NOME DE LOGRADOURO DO IMOVEL</th>
#       <th>NUMERO DO IMOVEL</th>
#       <th>COMPLEMENTO DO IMOVEL</th>
#       <th>BAIRRO DO IMOVEL</th>
#       <th>REFERENCIA DO IMOVEL</th>
#       <th>CEP DO IMOVEL</th>
#       <th>QUANTIDADE DE ESQUINAS/FRENTES</th>
#       <th>FRACAO IDEAL</th>
#       <th>AREA DO TERRENO</th>
#       <th>AREA CONSTRUIDA</th>
#       <th>AREA OCUPADA</th>
#       <th>VALOR DO M2 DO TERRENO</th>
#       <th>VALOR DO M2 DE CONSTRUCAO</th>
# ...

# %%
iptu.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3349769 entries, 0 to 3349768
# Data columns (total 33 columns):
# NUMERO DO CONTRIBUINTE                   3349769 non-null object
# ANO DO EXERCICIO                         3349769 non-null int64
# NUMERO DA NL                             3349769 non-null int64
# DATA DO CADASTRAMENTO                    3349769 non-null object
# TIPO DE CONTRIBUINTE 1                   3290332 non-null object
# NOME DO CONTRIBUINTE 1                   3349769 non-null object
# TIPO DE CONTRIBUINTE 2                   689587 non-null object
# NOME DO CONTRIBUINTE 2                   689891 non-null object
# NUMERO DO CONDOMINIO                     3349769 non-null object
# CODLOG DO IMOVEL                         3349769 non-null object
# NOME DE LOGRADOURO DO IMOVEL             3349769 non-null object
# NUMERO DO IMOVEL                         3258169 non-null float64
# COMPLEMENTO DO IMOVEL                    2377393 non-null object
# ...

# %%
iptu[["BAIRRO DO IMOVEL", "VALOR DO M2 DO TERRENO", "VALOR DO M2 DE CONSTRUCAO"]].dropna().groupby("BAIRRO DO IMOVEL").mean().to_csv("valor_por_bairro.csv", encoding="utf-8", index=False, sep=";")

# %%
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NUMERO DO CONTRIBUINTE</th>
#       <th>ANO DO EXERCICIO</th>
#       <th>NUMERO DA NL</th>
#       <th>DATA DO CADASTRAMENTO</th>
#       <th>TIPO DE CONTRIBUINTE 1</th>
#       <th>NOME DO CONTRIBUINTE 1</th>
#       <th>TIPO DE CONTRIBUINTE 2</th>
#       <th>NOME DO CONTRIBUINTE 2</th>
#       <th>NUMERO DO CONDOMINIO</th>
#       <th>CODLOG DO IMOVEL</th>
#       <th>NOME DE LOGRADOURO DO IMOVEL</th>
#       <th>NUMERO DO IMOVEL</th>
#       <th>COMPLEMENTO DO IMOVEL</th>
#       <th>BAIRRO DO IMOVEL</th>
#       <th>REFERENCIA DO IMOVEL</th>
#       <th>CEP DO IMOVEL</th>
#       <th>QUANTIDADE DE ESQUINAS/FRENTES</th>
#       <th>FRACAO IDEAL</th>
#       <th>AREA DO TERRENO</th>
#       <th>AREA CONSTRUIDA</th>
#       <th>AREA OCUPADA</th>
#       <th>VALOR DO M2 DO TERRENO</th>
#       <th>VALOR DO M2 DE CONSTRUCAO</th>
# ...

# %%
iptu["BAIRRO DO IMOVEL"].unique()
# Out:
# array(['SANTA EFIGENIA', nan, 'BOM RETIRO', ..., 'R.WILSON NAHRA N.88',
#        'ENTRADA P/RUA WILSON', 'ENTR.P/R.WILSON HAHRA'], dtype=object)

# %%
# iptu.to_csv("datasets/iptu-sp/iptu.csv", index=False, encoding="utf-8", sep=";")

# %% [markdown]
# ## Treating the data

# %% [markdown]
# Government's Patrimony
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106613 entries, 69485 to 656048
# Data columns (total 12 columns):
# id                      106613 non-null int64
# classe                  106613 non-null object
# numerodorip             106613 non-null int64
# uf                      106613 non-null object
# municipio               106613 non-null object
# endereco                106613 non-null object
# bairro                  106613 non-null object
# conceituacao            106613 non-null object
# tipoimovel              106613 non-null object
# situacaodautilizacao    106613 non-null object
# proprietariooficial     106613 non-null object
# regimedeutilizacao      106613 non-null object
# dtypes: int64(2), object(10)
# memory usage: 10.6+ MB
# ```
